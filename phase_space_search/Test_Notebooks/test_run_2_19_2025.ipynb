# %%
import sys
sys.path.append("C:/Users/labuser/Documents/git/LLPS_Project/phase_space_search/Flory_Classifier")
print(sys.path)

import flory_classifier_v2 
from flory_classifier_v2 import FloryClassifier
import h5py
import importlib
import numpy as np
import matplotlib.pyplot as plt
import os

importlib.reload(flory_classifier_v2)
# Out:
# ['C:\\Users\\labuser\\Documents\\git\\softliv', 'C:\\Users\\dm967\\Documents\\git\\softliv', 'c:\\Users\\labuser\\Documents\\git\\LLPS_Project\\phase_space_search', 'c:\\Users\\labuser\\.conda\\envs\\llps\\python313.zip', 'c:\\Users\\labuser\\.conda\\envs\\llps\\DLLs', 'c:\\Users\\labuser\\.conda\\envs\\llps\\Lib', 'c:\\Users\\labuser\\.conda\\envs\\llps', '', 'c:\\Users\\labuser\\.conda\\envs\\llps\\Lib\\site-packages', 'c:\\Users\\labuser\\.conda\\envs\\llps\\Lib\\site-packages\\win32', 'c:\\Users\\labuser\\.conda\\envs\\llps\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\labuser\\.conda\\envs\\llps\\Lib\\site-packages\\Pythonwin', '../..', '/Users/labuser/Documents/git/LLPS_Project/lab_work', '/Users/calvinsmith/dufresne_lab/multicomponent-mixtures-main', '/Users/calvinsmith/dufresne_lab/multicomponent-mixtures-main', '/Users/calvinsmith/dufresne_lab/phase_space_search', '../..', '/Users/labuser/Documents/git/LLPS_Project/lab_work', '/Users/calvinsmith/dufresne_lab/multicomponent-m
# ...

# %%
min_chi = 2
max_chi = 6
num_iters = 10
chi_strengths_set = np.linspace(min_chi,max_chi, num_iters)

# %%
folder_path = os.path.normpath(r"C:/Users/labuser/Documents/git/LLPS_Project/phase_space_search/Saved_Phase_Data/Test_Run_2_26_2025")                                   
num_comps = 3
num_chi_iters = 5
num_points_approx = 300

# %%
for i in range(num_iters):
    fc = FloryClassifier()
    chi_strength = chi_strengths_set[i]
    fc.reset_rand_chi_matrix(num_comps, chi_strength)
    file_path = fc.generate_grid_data_N_Dim_v2(num_chi_iters,num_points_approx, folder_path, False)
# Out:
# Reset CHI_MATRIX:
#  [[0.         3.42097123 1.78918856]
#  [3.42097123 0.         2.08850738]
#  [1.78918856 2.08850738 0.        ]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       3 chi_strength = chi_strengths_set[i]
#       4 fc.reset_rand_chi_matrix(num_comps, chi_strength)
# ----> 5 file_path = fc.generate_grid_data_N_Dim_v2(num_chi_iters,num_points_approx, folder_path, False)
#
# AttributeError: 'FloryClassifier' object has no attribute 'generate_grid_data_N_Dim_v2'
